# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#line plot
x = [0,1,2,3,4]
y= [0,2,4,6,8]

plt.plot(x,y)
plt.title('Line graph', fontsize= 12, loc='center')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.xticks([0,1,2,3,4])
plt.show()
